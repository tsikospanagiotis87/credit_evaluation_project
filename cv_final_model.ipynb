# %% [markdown]
# ----Importand Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# %%
df = pd.read_csv('full_train_set.csv', index_col= 0)

# %%
df.head()
# Out:
#   status  seniority     home  time  age    marital  records        job  \
# 0     no          6    owner    36   58    married   no_rec      fixed
# 1     no          9    owner    24   45    married   no_rec      fixed
# 2    yes          1     rent    48   37  separated  yes_rec      fixed
# 3     no          1  parents    24   19     single   no_rec      fixed
# 4     no         17     rent    24   50    married   no_rec  freelance
#
#    expenses  income   assets  debt  amount  price
# 0        60   390.0  45000.0   0.0    1000   2318
# 1        75   112.0   4000.0   0.0     500   1430
# 2        46   110.0      0.0   0.0     900   1312
# 3        35    28.0      0.0   0.0     400    600
# 4        68    79.0   1000.0   0.0    1000   3782

# %%
cat_columns = ['home', 'marital', 'records', 'job']

# %% [markdown]
# ----Building the Pipeline

# %%
ct = ColumnTransformer(transformers=[
    ('dummies', OneHotEncoder(handle_unknown= 'ignore'), cat_columns)],
    remainder= 'passthrough')

# %%
model = DecisionTreeClassifier(random_state= 1)

# %%
model_pipeline = Pipeline([
    ('transformer', ct),
    ('dt_model', model)
])

# %% [markdown]
# ----CV

# %%
max_depth = [4, 5, 7]
leaf_sample = [s for s in range(5, 105, 5)]
parameters = {'dt_model__max_depth': max_depth, 'dt_model__min_samples_leaf': leaf_sample}
metrics = ['roc_auc', 'accuracy']
X = df.iloc[:, 1:]
y = df.status.map({'no': 0, 'yes': 1})
cv = StratifiedKFold(
        n_splits= 10,
        shuffle= True, 
        random_state= 1)

# %%
cv_10 = GridSearchCV(estimator= model_pipeline,
             param_grid= parameters,
             scoring= metrics,
             refit= 'roc_auc',
             cv= cv,
             return_train_score= True, 
             n_jobs= -1)

# %%
cv_10.fit(X, y)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=1, shuffle=True),
#              estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('dummies',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['home',
#                                                                           'marital',
#                                                                           'records',
#                                                                           'job'])])),
#                                        ('dt_model',
#                                         DecisionTreeClassifier(random_state=1))]),
#              n_jobs=-1,
#              param_grid={'dt_model__max_depth': [4, 5, 7],
# ...

# %%
cv_10.best_params_
# Out:
# {'dt_model__max_depth': 7, 'dt_model__min_samples_leaf': 70}

# %%
cv_10.best_score_
# Out:
# np.float64(0.7957267630818775)

# %%
cv_df = pd.DataFrame(cv_10.cv_results_)

# %%
cv_df.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_dt_model__max_depth', 'param_dt_model__min_samples_leaf',
#        'params', 'split0_test_roc_auc', 'split1_test_roc_auc',
#        'split2_test_roc_auc', 'split3_test_roc_auc', 'split4_test_roc_auc',
#        'split5_test_roc_auc', 'split6_test_roc_auc', 'split7_test_roc_auc',
#        'split8_test_roc_auc', 'split9_test_roc_auc', 'mean_test_roc_auc',
#        'std_test_roc_auc', 'rank_test_roc_auc', 'split0_train_roc_auc',
#        'split1_train_roc_auc', 'split2_train_roc_auc', 'split3_train_roc_auc',
#        'split4_train_roc_auc', 'split5_train_roc_auc', 'split6_train_roc_auc',
#        'split7_train_roc_auc', 'split8_train_roc_auc', 'split9_train_roc_auc',
#        'mean_train_roc_auc', 'std_train_roc_auc', 'split0_test_accuracy',
#        'split1_test_accuracy', 'split2_test_accuracy', 'split3_test_accuracy',
# ...

# %%
cv_table = cv_df[['param_dt_model__max_depth', 'param_dt_model__min_samples_leaf', 'mean_test_roc_auc', 'mean_test_accuracy']]

# %%
pivot_cv_table_auc = cv_table.pivot(index= 'param_dt_model__min_samples_leaf', columns= 'param_dt_model__max_depth', values= 'mean_test_roc_auc')
pivot_cv_table_score = cv_table.pivot(index= 'param_dt_model__min_samples_leaf', columns= 'param_dt_model__max_depth', values= 'mean_test_accuracy')

# %%
cv_table[cv_table.mean_test_accuracy == cv_table.mean_test_accuracy.max()]
# Out:
#     param_dt_model__max_depth  param_dt_model__min_samples_leaf  \
# 50                          7                                55
#
#     mean_test_roc_auc  mean_test_accuracy
# 50           0.795335            0.774286

# %%
cv_table[cv_table.mean_test_roc_auc == cv_table.mean_test_roc_auc.max()]
# Out:
#     param_dt_model__max_depth  param_dt_model__min_samples_leaf  \
# 53                          7                                70
#
#     mean_test_roc_auc  mean_test_accuracy
# 53           0.795727            0.765143

# %%
fig, ax = plt.subplots(1, 2, figsize= (12, 5))
sn.heatmap(pivot_cv_table_auc, annot= True, ax= ax[0])
sn.heatmap(pivot_cv_table_score, annot= True, ax= ax[1])
plt.show()

# %%
"""There is an improvement about 2% when we use 7 layers depth in DT model than 5 or 4. As jump from 5 to 7 layers is computationally
   not too expensive we are going to train the final model using parameters max_depth=7 & min_sample_leaf=45"""
# Out:
# 'There is an improvement about 2% when we use 7 layers depth in DT model than 5 or 4. As jump from 5 to 7 layers is computationally\n   not too expensive we are going to train the final model using parameters max_depth=7 & min_sample_leaf=45'

# %% [markdown]
# ----Train, Evaluate and Save the Final Model on full train and test set

# %% [markdown]
# ---- --Training

# %%
final_pipeline = cv_10.best_estimator_

# %%
final_pipeline
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('dummies',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['home', 'marital', 'records',
#                                                    'job'])])),
#                 ('dt_model',
#                  DecisionTreeClassifier(max_depth=7, min_samples_leaf=70,
#                                         random_state=1))])

# %% [markdown]
# ---- --Evaluating

# %%
test_df = pd.read_csv('test_data_set.csv', index_col= 0)
X_test = test_df.iloc[:, 1:]
y_test = test_df.status.map({'no':0, 'yes':1})

# %%
from sklearn.metrics import roc_auc_score, recall_score, precision_score, accuracy_score

# %%
threshold = [t/100 for t in range(10, 85)]
recall_list = []
precision_list = []
acuracy_list = []
for t in threshold:
    y_pred_t = (final_pipeline.predict_proba(X_test)[:, 1] >= t).astype('int')
    recall = recall_score(y_test, y_pred_t)
    precision = precision_score(y_test, y_pred_t)
    score = accuracy_score(y_test, y_pred_t)
    recall_list.append(recall)
    precision_list.append(precision)
    acuracy_list.append(score)

# %%
plt.plot(threshold, recall_list, color= 'red', label= 'recall')
plt.plot(threshold, precision_list, color= 'green', label= 'precision')
plt.plot(threshold, acuracy_list, color= 'blue', label= 'acuracy_score')
plt.legend()
plt.xlabel('decision_treshold')
plt.ylabel('scores')
plt.show()

# %%
auc_score = roc_auc_score(y_test, final_pipeline.predict_proba(X_test)[:, 1])
auc_score
# Out:
# 0.8038983955826432

# %% [markdown]
# ---- --Saving

# %%
import joblib

# %%
# joblib.dump(final_pipeline, 'dt_pipeline.joblib')
# Out:
# ['dt_pipeline.joblib']
